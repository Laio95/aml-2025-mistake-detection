# %% [markdown]
# # Baseline Evaluation
# **Backbone:** Omnivore &nbsp;|&nbsp; **Models:** MLP · ErFormer (Transformer)
#
# Run cells top-to-bottom. Setup cells are safe to skip if the session is already configured.

# %% [markdown]
# ---
# ## Setup

# %%
# !git clone --recursive https://github.com/Laio95/aml-2025-mistake-detection.git code
# Out:
# Cloning into 'code'...
# remote: Enumerating objects: 538, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 538 (delta 138), reused 139 (delta 125), pack-reused 370 (from 2)
# Receiving objects: 100% (538/538), 2.48 MiB | 6.25 MiB/s, done.
# Resolving deltas: 100% (340/340), done.
# Submodule 'annotations' (https://github.com/CaptainCook4D/annotations) registered for path 'annotations'
# Cloning into '/content/code/annotations'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 152 (delta 75), reused 108 (delta 46), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 793.14 KiB | 3.02 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Submodule path 'annotations': checked out 'a8a920a3293c4db27099a20ddbe3a3a9be1283e3'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p code/features/
# !unzip "/content/drive/MyDrive/AML_Project/CaptainCook4D/1s.zip" -d code/features/
# Out:
# Archive:  /content/drive/MyDrive/AML_Project/CaptainCook4D/1s.zip
#    creating: code/features/1s/audio/
#   inflating: code/features/1s/text/text.zip
#   inflating: code/features/1s/video/slowfast.zip
#   inflating: code/features/1s/video/3dresnet.zip
#   inflating: code/features/1s/video/omnivore.zip
#   inflating: code/features/1s/video/x3d.zip

# %%
# !mkdir -p code/data/video/
# !unzip code/features/1s/video/omnivore.zip -d code/data/video/
# Out:
# Archive:  code/features/1s/video/omnivore.zip
#    creating: code/data/video/omnivore/
#   inflating: code/data/video/omnivore/22_37_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/28_38_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_17_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/20_16_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/13_14_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/10_7_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/22_2_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/21_47_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/28_42_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_39_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/2_8_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/29_28_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_23_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/20_26_360p.mp4_1s_1s.npz
# ...

# %%
# !mkdir -p code/checkpoints/
# !unzip "/content/drive/MyDrive/AML_Project/CaptainCook4D/error_recognition_best.zip" -d code/checkpoints/
# Out:
# Archive:  /content/drive/MyDrive/AML_Project/CaptainCook4D/error_recognition_best.zip
#   inflating: code/checkpoints/error_recognition_best/MLP/3dresnet/error_recognition_MLP_3dresnet_person_epoch_39.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/3dresnet/error_recognition_MLP_3dresnet_step_epoch_41.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/3dresnet/error_recognition_MLP_3dresnet_recordings_epoch_45.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/3dresnet/error_recognition_MLP_3dresnet_environment_epoch_11.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/imagebind/error_recognition_MLP_imagebind_audio_person_epoch_8.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/imagebind/error_recognition_MLP_imagebind_audio_step_epoch_28.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/imagebind/error_recognition_MLP_imagebind_audio_recordings_epoch_2.pt
# ...

# %%
# !pip install -q torcheval
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 7.9 MB/s eta 0:00:00

# %% [markdown]
# ---
# ## Baseline V1: MLP

# %% [markdown]
# **Model:** MLP &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `step` &nbsp;·&nbsp; **Threshold:** 0.6
#
# Expected &rarr; F1: **24.26%** &nbsp;|&nbsp; AUC: **75.74%**

# %%
# %%bash
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/MLP/omnivore/error_recognition_MLP_omnivore_step_epoch_43.pt \
#   --split step --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4096162736939436, 'recall': 0.2989708115404083, 'f1': 0.3456549302643129, 'accuracy': 0.6831416629277163, 'auc': np.float64(0.6541560352028618), 'pr_auc': tensor(0.3187)}
# test Step Level Metrics: {'precision': 0.6607142857142857, 'recall': 0.14859437751004015, 'f1': 0.24262295081967214, 'accuracy': 0.7105263157894737, 'auc': np.float64(0.7573902166041213), 'pr_auc': tensor(0.3638)}
# ----------------------------------------------------------------
# test Progress: 42347/798: 100%|██████████| 798/798 [00:05<00:00, 144.91it/s]

# %% [markdown]
# **Model:** MLP &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `recordings` &nbsp;·&nbsp; **Threshold:** 0.4
#
# Expected &rarr; F1: **55.42%** &nbsp;|&nbsp; AUC: **63.03%**

# %%
# %%bash
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/MLP/omnivore/error_recognition_MLP_omnivore_recordings_epoch_33.pt \
#   --split recordings --threshold 0.4
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.3964945261528254, 'recall': 0.5688109780280797, 'f1': 0.46727266803505685, 'accuracy': 0.5735263432446531, 'auc': np.float64(0.5988330748775713), 'pr_auc': tensor(0.3673)}
# test Step Level Metrics: {'precision': 0.4090909090909091, 'recall': 0.8589211618257261, 'f1': 0.5542168674698795, 'accuracy': 0.503725782414307, 'auc': np.float64(0.6302808067162018), 'pr_auc': tensor(0.4020)}
# ----------------------------------------------------------------
# test Progress: 38340/671: 100%|██████████| 671/671 [00:04<00:00, 146.43it/s]

# %% [markdown]
# ---
# ## Baseline V2: ErFormer (Transformer)

# %% [markdown]
# **Model:** Transformer &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `step` &nbsp;·&nbsp; **Threshold:** 0.6
#
# Expected &rarr; F1: **55.39%** &nbsp;|&nbsp; AUC: **75.62%**

# %%
# %%bash
# cd code
# python -m core.evaluate --variant Transformer --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/Transformer/omnivore/error_recognition_Transformer_omnivore_step_epoch_9.pt \
#   --split step --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4445452483556362, 'recall': 0.6613801248523705, 'f1': 0.5317056629365887, 'accuracy': 0.6738848088412402, 'auc': np.float64(0.7461755308526944), 'pr_auc': tensor(0.3888)}
# test Step Level Metrics: {'precision': 0.5155709342560554, 'recall': 0.5983935742971888, 'f1': 0.5539033457249071, 'accuracy': 0.6992481203007519, 'auc': np.float64(0.7561832027563805), 'pr_auc': tensor(0.4338)}
# ----------------------------------------------------------------
# test Progress: 42347/798: 100%|██████████| 798/798 [00:06<00:00, 132.26it/s]

# %% [markdown]
# **Model:** Transformer &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `recordings` &nbsp;·&nbsp; **Threshold:** 0.4
#
# Expected &rarr; F1: **40.73%** &nbsp;|&nbsp; AUC: **62.27%**

# %%
# %%bash
# cd code
# python -m core.evaluate --variant Transformer --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/Transformer/omnivore/error_recognition_Transformer_omnivore_recordings_epoch_31.pt \
#   --split recordings --threshold 0.4
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4491327720864185, 'recall': 0.35123344173871657, 'f1': 0.39419567346212053, 'accuracy': 0.645018257694314, 'auc': np.float64(0.6254427005929003), 'pr_auc': tensor(0.3711)}
# test Step Level Metrics: {'precision': 0.45408163265306123, 'recall': 0.36929460580912865, 'f1': 0.4073226544622426, 'accuracy': 0.6140089418777943, 'auc': np.float64(0.6226768310334846), 'pr_auc': tensor(0.3942)}
# ----------------------------------------------------------------
# test Progress: 38340/671: 100%|██████████| 671/671 [00:04<00:00, 135.51it/s]

# %% [markdown]
# ---
# ## Summary — Expected Results
#
# | Model       | Split        | Threshold | F1 (%)  | AUC (%) |
# |-------------|--------------|-----------|--------:|--------:|
# | MLP         | step         | 0.6       | 24.26   | 75.74   |
# | MLP         | recordings   | 0.4       | 55.42   | 63.03   |
# | Transformer | step         | 0.6       | 55.39   | 75.62   |
# | Transformer | recordings   | 0.4       | 40.73   | 62.27   |
