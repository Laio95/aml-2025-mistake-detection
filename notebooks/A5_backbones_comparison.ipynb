# %% [markdown]
# # Backbones Evaluation
# **Backbones:** Omnivore · EgoVLP &nbsp;|&nbsp; **Models:** MLP · ErFormer (Transformer) · LSTM

# %% [markdown]
# ---
# ## Setup

# %%
# !git clone --recursive https://github.com/Laio95/aml-2025-mistake-detection.git code
# Out:
# Cloning into 'code'...
# remote: Enumerating objects: 801, done.
# remote: Counting objects: 100% (219/219), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 801 (delta 157), reused 158 (delta 142), pack-reused 582 (from 3)
# Receiving objects: 100% (801/801), 7.08 MiB | 10.10 MiB/s, done.
# Resolving deltas: 100% (491/491), done.
# Updating files: 100% (56/56), done.
# Submodule 'actionformer_release' (https://github.com/rohithpeddi/actionformer_release.git) registered for path 'actionformer_release'
# Submodule 'annotations' (https://github.com/CaptainCook4D/annotations) registered for path 'annotations'
# Cloning into '/content/code/actionformer_release'...
# remote: Enumerating objects: 410, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 410 (delta 16), reused 6 (delta 6), pack-reused 384 (from 2)
# Receiving objects: 100% (410/410), 651.07 KiB | 14.80 MiB/s, done.
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p code/features/
# !unzip "/content/drive/MyDrive/AML_Project/CaptainCook4D/1s.zip" -d code/features/
# Out:
# Archive:  /content/drive/MyDrive/AML_Project/CaptainCook4D/1s.zip
#    creating: code/features/1s/audio/
#   inflating: code/features/1s/text/text.zip
#   inflating: code/features/1s/video/slowfast.zip
#   inflating: code/features/1s/video/3dresnet.zip
#   inflating: code/features/1s/video/omnivore.zip
#   inflating: code/features/1s/video/x3d.zip

# %%
# !mkdir -p code/data/video/
# !unzip code/features/1s/video/omnivore.zip -d code/data/video/
# Out:
# Archive:  code/features/1s/video/omnivore.zip
#    creating: code/data/video/omnivore/
#   inflating: code/data/video/omnivore/22_37_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/28_38_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_17_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/20_16_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/13_14_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/10_7_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/22_2_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/21_47_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/28_42_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_39_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/2_8_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/29_28_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_23_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/20_26_360p.mp4_1s_1s.npz
# ...

# %%
# !mkdir -p code/checkpoints/
# !unzip "/content/drive/MyDrive/AML_Project/CaptainCook4D/error_recognition_best.zip" -d code/checkpoints/
# Out:
# Archive:  /content/drive/MyDrive/AML_Project/CaptainCook4D/error_recognition_best.zip
#   inflating: code/checkpoints/error_recognition_best/MLP/3dresnet/error_recognition_MLP_3dresnet_person_epoch_39.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/3dresnet/error_recognition_MLP_3dresnet_step_epoch_41.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/3dresnet/error_recognition_MLP_3dresnet_recordings_epoch_45.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/3dresnet/error_recognition_MLP_3dresnet_environment_epoch_11.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/imagebind/error_recognition_MLP_imagebind_audio_person_epoch_8.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/imagebind/error_recognition_MLP_imagebind_audio_step_epoch_28.pt
#   inflating: code/checkpoints/error_recognition_best/MLP/imagebind/error_recognition_MLP_imagebind_audio_recordings_epoch_2.pt
# ...

# %%
# !mkdir code/data/video/egovlp

# !cp -r /content/drive/MyDrive/AML_Project/CaptainCook4D/features_egovlp_num_frames_4/* code/data/video/egovlp
print("Copy complete.")
# Out:
# Copy complete.

# %%
# !pip install -q torcheval
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 15.3 MB/s eta 0:00:00

# %% [markdown]
# ---
# ## Step 2 — Baseline V1: MLP

# %% [markdown]
# **Model:** MLP &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `step` &nbsp;·&nbsp; **Threshold:** 0.6
#
# Expected &rarr; F1: **24.26%** &nbsp;|&nbsp; AUC: **75.74%**

# %%
# %%bash
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/MLP/omnivore/error_recognition_MLP_omnivore_step_epoch_43.pt \
#   --split step --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4096162736939436, 'recall': 0.2989708115404083, 'f1': 0.3456549302643129, 'accuracy': 0.6831416629277163, 'auc': np.float64(0.6541560352028618), 'pr_auc': tensor(0.3187)}
# test Step Level Metrics: {'precision': 0.6607142857142857, 'recall': 0.14859437751004015, 'f1': 0.24262295081967214, 'accuracy': 0.7105263157894737, 'auc': np.float64(0.7573902166041213), 'pr_auc': tensor(0.3638)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.1739, 'recall': 0.0952, 'f1': 0.1231, 'auc': np.float64(0.7172), 'support': 42}
# {'Category': 'Preparation Error', 'precision': 0.2963, 'recall': 0.1633, 'f1': 0.2105, 'auc': np.float64(0.759), 'support': 49}
# ...

# %% [markdown]
# **Model:** MLP &nbsp;·&nbsp; **Backbone:** EgoVLP &nbsp;·&nbsp; **Split:** `step` &nbsp;·&nbsp; **Threshold:** 0.6

# %%
# %%bash
#
# cd code
#
# python -m core.evaluate \
#     --variant   MLP \
#     --backbone  egovlp \
#     --split     step \
#     --threshold 0.6 \
#     --ckpt      "/content/drive/MyDrive/AML_Project/models/error_recognition/MLP/egovlp/error_recognition_step_egovlp_MLP_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.45175522731632456, 'recall': 0.3973342331702379, 'f1': 0.4228007181328546, 'accuracy': 0.6963185113467306, 'auc': np.float64(0.6890106991063139), 'pr_auc': tensor(0.3482)}
# test Step Level Metrics: {'precision': 0.5958549222797928, 'recall': 0.46184738955823296, 'f1': 0.5203619909502263, 'accuracy': 0.7343358395989975, 'auc': np.float64(0.7798918808201841), 'pr_auc': tensor(0.4431)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.22, 'recall': 0.5238, 'f1': 0.3099, 'auc': np.float64(0.8427), 'support': 42}
# {'Category': 'Preparation Error', 'precision': 0.22, 'recall': 0.449, 'f1': 0.2953, 'auc': np.float64(0.7466), 'support': 49}
# ...

# %% [markdown]
# **Model:** MLP &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `recordings` &nbsp;·&nbsp; **Threshold:** 0.4
#
# Expected &rarr; F1: **55.42%** &nbsp;|&nbsp; AUC: **63.03%**

# %%
# %%bash
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/MLP/omnivore/error_recognition_MLP_omnivore_recordings_epoch_33.pt \
#   --split recordings --threshold 0.4
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.3964945261528254, 'recall': 0.5688109780280797, 'f1': 0.46727266803505685, 'accuracy': 0.5735263432446531, 'auc': np.float64(0.5988330748775713), 'pr_auc': tensor(0.3673)}
# test Step Level Metrics: {'precision': 0.4090909090909091, 'recall': 0.8589211618257261, 'f1': 0.5542168674698795, 'accuracy': 0.503725782414307, 'auc': np.float64(0.6302808067162018), 'pr_auc': tensor(0.4020)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.1333, 'recall': 0.92, 'f1': 0.2329, 'auc': np.float64(0.7162), 'support': 50}
# {'Category': 'Preparation Error', 'precision': 0.1232, 'recall': 0.8571, 'f1': 0.2154, 'auc': np.float64(0.6449), 'support': 49}
# ...

# %% [markdown]
# **Model:** MLP &nbsp;·&nbsp; **Backbone:** EgoVLP &nbsp;·&nbsp; **Split:** `recordings` &nbsp;·&nbsp; **Threshold:** 0.4

# %%
# %%bash
#
# cd code
#
# python -m core.evaluate \
#     --variant   MLP \
#     --backbone  egovlp \
#     --split     recordings \
#     --threshold 0.4 \
#     --ckpt      "/content/drive/MyDrive/AML_Project/models/error_recognition/MLP/egovlp/error_recognition_recordings_egovlp_MLP_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.40514689136870874, 'recall': 0.28222416118029664, 'f1': 0.3326943756136332, 'accuracy': 0.6277256129368806, 'auc': np.float64(0.5896304241606434), 'pr_auc': tensor(0.3504)}
# test Step Level Metrics: {'precision': 0.43915343915343913, 'recall': 0.6887966804979253, 'f1': 0.5363489499192245, 'accuracy': 0.5722801788375559, 'auc': np.float64(0.6289973945768599), 'pr_auc': tensor(0.4143)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.1587, 'recall': 0.8, 'f1': 0.2649, 'auc': np.float64(0.7118), 'support': 50}
# {'Category': 'Preparation Error', 'precision': 0.1311, 'recall': 0.6531, 'f1': 0.2184, 'auc': np.float64(0.6062), 'support': 49}
# ...

# %% [markdown]
# ---
# ## Step 3 — Baseline V2: ErFormer (Transformer)

# %% [markdown]
# **Model:** Transformer &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `step` &nbsp;·&nbsp; **Threshold:** 0.6
#
# Expected &rarr; F1: **55.39%** &nbsp;|&nbsp; AUC: **75.62%**

# %%
# %%bash
# cd code
# python -m core.evaluate --variant Transformer --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/Transformer/omnivore/error_recognition_Transformer_omnivore_step_epoch_9.pt \
#   --split step --threshold 0.6
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4445452483556362, 'recall': 0.6613801248523705, 'f1': 0.5317056629365887, 'accuracy': 0.6738848088412402, 'auc': np.float64(0.7461755308526944), 'pr_auc': tensor(0.3888)}
# test Step Level Metrics: {'precision': 0.5155709342560554, 'recall': 0.5983935742971888, 'f1': 0.5539033457249071, 'accuracy': 0.6992481203007519, 'auc': np.float64(0.7561832027563805), 'pr_auc': tensor(0.4338)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.1617, 'recall': 0.6429, 'f1': 0.2584, 'auc': np.float64(0.777), 'support': 42}
# {'Category': 'Preparation Error', 'precision': 0.1765, 'recall': 0.6122, 'f1': 0.274, 'auc': np.float64(0.7676), 'support': 49}
# ...

# %% [markdown]
# **Model:** Transformer &nbsp;·&nbsp; **Backbone:** EgoVLP &nbsp;·&nbsp; **Split:** `step` &nbsp;·&nbsp; **Threshold:** 0.6

# %%
# %%bash
#
# cd code
#
# python -m core.evaluate \
#     --variant   Transformer \
#     --backbone  egovlp \
#     --split     step \
#     --threshold 0.6 \
#     --ckpt      "/content/drive/MyDrive/AML_Project/models/error_recognition/Transformer/egovlp/error_recognition_step_egovlp_Transformer_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 1.0, 'recall': 0.0029525898430909398, 'f1': 0.005887795441164101, 'accuracy': 0.72090112640801, 'auc': np.float64(0.6636833222643663), 'pr_auc': tensor(0.2821)}
# test Step Level Metrics: {'precision': 0.8571428571428571, 'recall': 0.024096385542168676, 'f1': 0.046875, 'accuracy': 0.6942355889724311, 'auc': np.float64(0.6756717214943562), 'pr_auc': tensor(0.3252)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.75, 'recall': 0.0714, 'f1': 0.1304, 'auc': np.float64(0.739), 'support': 42}
# {'Category': 'Preparation Error', 'precision': 0.5, 'recall': 0.0204, 'f1': 0.0392, 'auc': np.float64(0.6407), 'support': 49}
# {'Category': 'Technique Error', 'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'auc': np.float64(0.6172), 'support': 62}
# ...

# %% [markdown]
# **Model:** Transformer &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `recordings` &nbsp;·&nbsp; **Threshold:** 0.4
#
# Expected &rarr; F1: **40.73%** &nbsp;|&nbsp; AUC: **62.27%**

# %%
# %%bash
# cd code
# python -m core.evaluate --variant Transformer --backbone omnivore \
#   --ckpt checkpoints/error_recognition_best/Transformer/omnivore/error_recognition_Transformer_omnivore_recordings_epoch_31.pt \
#   --split recordings --threshold 0.4
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4491327720864185, 'recall': 0.35123344173871657, 'f1': 0.39419567346212053, 'accuracy': 0.645018257694314, 'auc': np.float64(0.6254427005929003), 'pr_auc': tensor(0.3711)}
# test Step Level Metrics: {'precision': 0.45408163265306123, 'recall': 0.36929460580912865, 'f1': 0.4073226544622426, 'accuracy': 0.6140089418777943, 'auc': np.float64(0.6226768310334846), 'pr_auc': tensor(0.3942)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.2246, 'recall': 0.62, 'f1': 0.3298, 'auc': np.float64(0.7049), 'support': 50}
# {'Category': 'Preparation Error', 'precision': 0.1371, 'recall': 0.3469, 'f1': 0.1965, 'auc': np.float64(0.615), 'support': 49}
# ...

# %% [markdown]
# **Model:** Transformer &nbsp;·&nbsp; **Backbone:** EgoVLP &nbsp;·&nbsp; **Split:** `recordings` &nbsp;·&nbsp; **Threshold:** 0.4

# %%
# %%bash
#
# cd code
#
# python -m core.evaluate \
#     --variant   Transformer \
#     --backbone  egovlp \
#     --split     recordings \
#     --threshold 0.4 \
#     --ckpt      "/content/drive/MyDrive/AML_Project/models/error_recognition/Transformer/egovlp/error_recognition_recordings_egovlp_Transformer_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.48697394789579157, 'recall': 0.15420004759260728, 'f1': 0.23423097776974516, 'accuracy': 0.6684663536776213, 'auc': np.float64(0.6044572962108942), 'pr_auc': tensor(0.3532)}
# test Step Level Metrics: {'precision': 0.45161290322580644, 'recall': 0.17427385892116182, 'f1': 0.25149700598802394, 'accuracy': 0.6274217585692996, 'auc': np.float64(0.5981569043713211), 'pr_auc': tensor(0.3753)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.1905, 'recall': 0.24, 'f1': 0.2124, 'auc': np.float64(0.6721), 'support': 50}
# {'Category': 'Preparation Error', 'precision': 0.1207, 'recall': 0.1429, 'f1': 0.1308, 'auc': np.float64(0.5504), 'support': 49}
# ...

# %% [markdown]
# ## Step 4 — Baseline Extra: LSTM

# %% [markdown]
# **Model:** LSTM &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `step` &nbsp;·&nbsp; **Threshold:** 0.6

# %%
# %%bash
#
# cd code
#
# python -m core.evaluate \
#     --variant   LSTM \
#     --backbone  omnivore \
#     --split     step \
#     --threshold 0.6 \
#     --ckpt      "/content/drive/MyDrive/AML_Project/models/error_recognition/LSTM/omnivore/error_recognition_step_omnivore_LSTM_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4763670064874884, 'recall': 0.47696979922389066, 'f1': 0.47666821228343803, 'accuracy': 0.706826929888776, 'auc': np.float64(0.6953022505791738), 'pr_auc': tensor(0.3736)}
# test Step Level Metrics: {'precision': 0.5815217391304348, 'recall': 0.42971887550200805, 'f1': 0.4942263279445728, 'accuracy': 0.7255639097744361, 'auc': np.float64(0.7218820637742226), 'pr_auc': tensor(0.4278)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.2143, 'recall': 0.5, 'f1': 0.3, 'auc': np.float64(0.732), 'support': 42}
# {'Category': 'Preparation Error', 'precision': 0.23, 'recall': 0.4694, 'f1': 0.3087, 'auc': np.float64(0.7005), 'support': 49}
# ...

# %% [markdown]
# **Model:** LSTM &nbsp;·&nbsp; **Backbone:** EgoVLP &nbsp;·&nbsp; **Split:** `step` &nbsp;·&nbsp; **Threshold:** 0.6

# %%
# %%bash
#
# cd code
#
# python -m core.evaluate \
#     --variant   LSTM \
#     --backbone  egovlp \
#     --split     step \
#     --threshold 0.6 \
#     --ckpt      "/content/drive/MyDrive/AML_Project/models/error_recognition/LSTM/egovlp/error_recognition_step_egovlp_LSTM_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.5305731263178072, 'recall': 0.23350767673359205, 'f1': 0.3242926600667799, 'accuracy': 0.7276076227359671, 'auc': np.float64(0.666754966833186), 'pr_auc': tensor(0.3385)}
# test Step Level Metrics: {'precision': 0.5930232558139535, 'recall': 0.20481927710843373, 'f1': 0.3044776119402985, 'accuracy': 0.7080200501253133, 'auc': np.float64(0.6684954755268799), 'pr_auc': tensor(0.3696)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.2391, 'recall': 0.2619, 'f1': 0.25, 'auc': np.float64(0.6635), 'support': 42}
# {'Category': 'Preparation Error', 'precision': 0.2222, 'recall': 0.2041, 'f1': 0.2128, 'auc': np.float64(0.6504), 'support': 49}
# ...

# %% [markdown]
# **Model:** LSTM &nbsp;·&nbsp; **Backbone:** Omnivore &nbsp;·&nbsp; **Split:** `recordings` &nbsp;·&nbsp; **Threshold:** 0.4

# %%
# %%bash
#
# cd code
#
# python -m core.evaluate \
#     --variant   LSTM \
#     --backbone  omnivore \
#     --split     recordings \
#     --threshold 0.4 \
#     --ckpt      "/content/drive/MyDrive/AML_Project/models/error_recognition/LSTM/omnivore/error_recognition_recordings_omnivore_LSTM_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4228456913827655, 'recall': 0.3347346712144047, 'f1': 0.3736662682073759, 'accuracy': 0.6310119979134063, 'auc': np.float64(0.6007318241100805), 'pr_auc': tensor(0.3603)}
# test Step Level Metrics: {'precision': 0.4934210526315789, 'recall': 0.3112033195020747, 'f1': 0.3816793893129771, 'accuracy': 0.6378539493293591, 'auc': np.float64(0.6253112033195021), 'pr_auc': tensor(0.4009)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.2376, 'recall': 0.48, 'f1': 0.3179, 'auc': np.float64(0.7135), 'support': 50}
# {'Category': 'Preparation Error', 'precision': 0.1444, 'recall': 0.2653, 'f1': 0.1871, 'auc': np.float64(0.6409), 'support': 49}
# ...

# %% [markdown]
# **Model:** LSTM &nbsp;·&nbsp; **Backbone:** EgoVLP &nbsp;·&nbsp; **Split:** `recordings` &nbsp;·&nbsp; **Threshold:** 0.4

# %%
# %%bash
#
# cd code
#
# python -m core.evaluate \
#     --variant   LSTM \
#     --backbone  egovlp \
#     --split     recordings \
#     --threshold 0.4 \
#     --ckpt      "/content/drive/MyDrive/AML_Project/models/error_recognition/LSTM/egovlp/error_recognition_recordings_egovlp_LSTM_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4488419158983584, 'recall': 0.47497422067105577, 'f1': 0.46153846153846156, 'accuracy': 0.6355764214919144, 'auc': np.float64(0.5907788141267329), 'pr_auc': tensor(0.3858)}
# test Step Level Metrics: {'precision': 0.4619289340101523, 'recall': 0.3775933609958506, 'f1': 0.4155251141552511, 'accuracy': 0.6184798807749627, 'auc': np.float64(0.5848209977805655), 'pr_auc': tensor(0.3980)}
# test Category Step Level Metrics:
#
# {'Category': 'Measurement Error', 'precision': 0.1908, 'recall': 0.5, 'f1': 0.2762, 'auc': np.float64(0.63), 'support': 50}
# {'Category': 'Preparation Error', 'precision': 0.1382, 'recall': 0.3469, 'f1': 0.1977, 'auc': np.float64(0.5424), 'support': 49}
# ...

# %% [markdown]
# ---
# ## Summary — Obtained Results
#
# | Model       | Split        | Backbone | F1 (%)  | AUC (%) |
# |-------------|--------------|-----------|--------:|--------:|
# | MLP         | step         | omnivore       | 24.26   | 75.74   |
# | MLP         | recordings   | omnivore       | 55.42   | 63.03   |
# | MLP         | step         | egovlp         | 52.04   | 77.99   |
# | MLP         | recordings   | egovlp         | 53.63   | 62.90   |
# | Transformer | step         | omnivore       | 55.39   | 75.62   |
# | Transformer | recordings   | omnivore       | 40.73   | 62.27   |
# | Transformer | step         | egovlp         | 04.69   | 57.67   |
# | Transformer | recordings   | egovlp         | 25.15   | 59.82   |
# | LSTM        | step         | omnivore       | 49.42   | 72.19   |
# | LSTM        | recordings   | omnivore       | 38.17   | 62.53   |
# | LSTM        | step         | egovlp         | 30.45   | 66.85   |
# | LSTM        | recordings   | egovlp         | 41.55   | 58.48   |

# %% [markdown]
# ### Comparison: F1 Score (%) per Category
#
# | Category | MLP-Omni (Step) | MLP-Omni (Rec) | MLP-Ego (Step) | MLP-Ego (Rec) | TF-Omni (Step) | TF-Omni (Rec) | TF-Ego (Step) | TF-Ego (Rec) | LSTM-Omni (Step) | LSTM-Omni (Rec) | LSTM-Ego (Step) | LSTM-Ego (Rec) |
# | :--- | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | **Measurement** | 12.31 | 23.29 | 30.99 | 26.49 | 25.84 | 32.98 | 13.04 | 21.24 | 30.00 | 31.79 | 25.00 | 27.62 |
# | **Preparation** | 21.05 | 21.54 | 29.53 | 21.84 | 27.40 | 19.65 | 03.92 | 13.08 | 30.87 | 18.71 | 21.28 | 19.77 |
# | **Technique**   | 29.47 | 25.79 | 31.33 | 26.28 | 27.35 | 27.08 | 00.00 | 16.67 | 30.49 | 24.52 | 18.69 | 22.58 |
# | **Temperature** | 00.00 | 05.08 | 08.89 | 05.31 | 05.26 | 01.72 | 00.00 | 03.33 | 04.60 | 06.82 | 13.04 | 05.13 |
# | **Timing**      | 07.27 | 13.22 | 25.00 | 15.50 | 21.54 | 10.00 | 05.56 | 05.06 | 25.20 | 12.73 | 10.96 | 16.67 |

# %% [markdown]
# ### Comparison: AUC (%) per Category
#
# | Category | MLP-Omni (Step) | MLP-Omni (Rec) | MLP-Ego (Step) | MLP-Ego (Rec) | TF-Omni (Step) | TF-Omni (Rec) | TF-Ego (Step) | TF-Ego (Rec) | LSTM-Omni (Step) | LSTM-Omni (Rec) | LSTM-Ego (Step) | LSTM-Ego (Rec) |
# | :--- | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | **Measurement** | 71.72 | 71.62 | 84.27 | 71.18 | 77.70 | 70.49 | 73.90 | 67.21 | 73.20 | 71.35 | 66.35 | 63.00 |
# | **Preparation** | 75.90 | 64.49 | 74.66 | 60.62 | 76.76 | 61.50 | 64.07 | 55.04 | 70.05 | 64.09 | 65.04 | 54.24 |
# | **Technique**   | 77.28 | 63.39 | 75.22 | 64.84 | 70.43 | 68.55 | 61.72 | 58.88 | 73.84 | 63.30 | 63.11 | 59.41 |
# | **Temperature** | 80.03 | 72.99 | 85.86 | 71.80 | 77.60 | 44.45 | 79.80 | 57.88 | 61.68 | 69.77 | 73.04 | 64.65 |
# | **Timing**      | 73.50 | 60.01 | 78.40 | 64.84 | 76.20 | 59.53 | 71.56 | 58.00 | 70.57 | 50.35 | 68.47 | 57.12 |
