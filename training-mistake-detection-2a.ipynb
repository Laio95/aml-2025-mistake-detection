# %%
# !git clone --recursive https://github.com/Laio95/aml-2025-mistake-detection.git code
# Out:
# Cloning into 'code'...
# remote: Enumerating objects: 446, done.
# remote: Counting objects: 100% (141/141), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 446 (delta 120), reused 120 (delta 115), pack-reused 305 (from 1)
# Receiving objects: 100% (446/446), 133.18 KiB | 6.66 MiB/s, done.
# Resolving deltas: 100% (290/290), done.
# Submodule 'annotations' (https://github.com/CaptainCook4D/annotations) registered for path 'annotations'
# Cloning into '/content/code/annotations'...
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 152 (delta 75), reused 108 (delta 46), pack-reused 0 (from 0)
# Receiving objects: 100% (152/152), 793.14 KiB | 14.96 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# Submodule path 'annotations': checked out '0e9a108be2cbcbcbd592e7418c0ab9c16232d27a'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install -r code/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 12.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 64.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 18.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 kB 12.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# TODO: update the paths below with your own
# !mkdir code/data
# !mkdir code/data/features
# !unzip "/content/drive/MyDrive/AML_Project/CaptainCook4D/1s.zip" -d code/data/features

#!mkdir code/checkpoints
#!unzip "/content/drive/MyDrive/AML_Project/CaptainCook4D/error_recognition_best.zip" -d code/checkpoints/
# Out:
# Archive:  /content/drive/MyDrive/AML_Project/CaptainCook4D/1s.zip
#    creating: code/data/features/1s/audio/
#   inflating: code/data/features/1s/text/text.zip
#   inflating: code/data/features/1s/video/slowfast.zip
#   inflating: code/data/features/1s/video/3dresnet.zip
#   inflating: code/data/features/1s/video/omnivore.zip
#   inflating: code/data/features/1s/video/x3d.zip

# %%
# !mkdir code/data/video/
# !unzip code/data/features/1s/video/omnivore.zip -d code/data/video/
# Out:
# Archive:  code/data/features/1s/video/omnivore.zip
#    creating: code/data/video/omnivore/
#   inflating: code/data/video/omnivore/22_37_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/28_38_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_17_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/20_16_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/13_14_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/10_7_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/22_2_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/21_47_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/28_42_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_39_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/2_8_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/29_28_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/16_23_360p.mp4_1s_1s.npz
#   inflating: code/data/video/omnivore/20_26_360p.mp4_1s_1s.npz
# ...

# %%
# !wandb login
# Out:
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: albertogiunti2001 (albertogiunti2001-politecnico-di-torino) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %%
# %%bash
#
# cd code
# python train_er.py --num_epochs 50 --batch_size 512 --variant MLP \
# --backbone omnivore --split step \
# --ckpt_directory "/content/drive/MyDrive/AML_Project/models"
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --split step --threshold 0.6 \
#   --ckpt "/content/drive/MyDrive/AML_Project/models/error_recognition_step_omnivore_MLP_video_best_2.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.43071833118376046, 'recall': 0.6479669309937574, 'f1': 0.5174655573146495, 'accuracy': 0.6617233806408954, 'auc': np.float64(0.7203098680731218), 'pr_auc': tensor(0.3776)}
# test Step Level Metrics: {'precision': 0.6595744680851063, 'recall': 0.4979919678714859, 'f1': 0.5675057208237986, 'accuracy': 0.7631578947368421, 'auc': np.float64(0.8412374452271747), 'pr_auc': tensor(0.4851)}
# ----------------------------------------------------------------
# test Progress: 42347/798: 100%|██████████| 798/798 [00:04<00:00, 167.38it/s]

# %%
# %%bash
#
# cd code
# python train_er.py --num_epochs 50 --batch_size 512 --variant MLP \
# --backbone omnivore --split recordings \
# --ckpt_directory "/content/drive/MyDrive/AML_Project/models"
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant MLP --backbone omnivore \
#   --split recordings --threshold 0.4 \
#   --ckpt "/content/drive/MyDrive/AML_Project/models/error_recognition_recordings_omnivore_MLP_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.4166613141499133, 'recall': 0.5145554057269771, 'f1': 0.4604628052243044, 'accuracy': 0.6034950443401148, 'auc': np.float64(0.617688959917323), 'pr_auc': tensor(0.3740)}
# test Step Level Metrics: {'precision': 0.44212962962962965, 'recall': 0.7925311203319502, 'f1': 0.5676077265973254, 'accuracy': 0.5663189269746647, 'auc': np.float64(0.646347582746309), 'pr_auc': tensor(0.4249)}
# ----------------------------------------------------------------
# test Progress: 38340/671: 100%|██████████| 671/671 [00:04<00:00, 153.52it/s]

# %%
# %%bash
#
# cd code
# python train_er.py --num_epochs 50 --batch_size 1 --lr 1e-5 \
# --backbone omnivore --split step \
# --ckpt_directory "/content/drive/MyDrive/AML_Project/models/"
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant Transformer --backbone omnivore \
#   --split step --threshold 0.6 \
#   --ckpt "/content/drive/MyDrive/AML_Project/models/error_recognition_step_omnivore_Transformer_video_best.pt"  # TODO insert my path
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.5757623388871425, 'recall': 0.3090096170069175, 'f1': 0.40217391304347827, 'accuracy': 0.7428389260160105, 'auc': np.float64(0.7337681978208056), 'pr_auc': tensor(0.3713)}
# test Step Level Metrics: {'precision': 0.5864661654135338, 'recall': 0.3132530120481928, 'f1': 0.4083769633507853, 'accuracy': 0.7167919799498746, 'auc': np.float64(0.7313114022574816), 'pr_auc': tensor(0.3980)}
# ----------------------------------------------------------------
# test Progress: 42347/798: 100%|██████████| 798/798 [00:05<00:00, 133.90it/s]

# %%
# %%bash
#
# cd code
# python train_er.py --num_epochs 50 --batch_size 1 --lr 1e-5 --variant Transformer \
# --backbone omnivore --split recordings \
# --ckpt_directory "/content/drive/MyDrive/AML_Project/models/"
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %%bash
#
# cd code
# python -m core.evaluate --variant Transformer --backbone omnivore \
#   --split recordings --threshold 0.4 \
#   --ckpt "/content/drive/MyDrive/AML_Project/models/error_recognition_recordings_omnivore_Transformer_video_best.pt"
# Out:
# Loaded annotations......
# Loading recording ids from recordings_combined_splits.json
# ----------------------------------------------------------------
# test Sub Step Level Metrics: {'precision': 0.5825676682393841, 'recall': 0.18608709447132546, 'f1': 0.28207286281110977, 'accuracy': 0.6885237350026082, 'auc': np.float64(0.6687682239624663), 'pr_auc': tensor(0.3760)}
# test Step Level Metrics: {'precision': 0.5581395348837209, 'recall': 0.1991701244813278, 'f1': 0.29357798165137616, 'accuracy': 0.6557377049180327, 'auc': np.float64(0.6692946058091287), 'pr_auc': tensor(0.3988)}
# ----------------------------------------------------------------
# test Progress: 38340/671: 100%|██████████| 671/671 [00:04<00:00, 142.55it/s]
